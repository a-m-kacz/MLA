# %% [markdown]
# <a href="https://colab.research.google.com/github/a-m-kacz/MLA/blob/main/Kopia_notatnika_mnist_in_3_flavours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classification of handwritten digits using various neural network models with PyTorch
# * Multinomial classification task of images of handwritten digits (10 classes).
# * The database has a training set of 60k examples, and a test set of 10k examples, each image is of 28x28 pixels size.
# * The MNIST ("Modified National Institute of Standards and Technology") is the “hello world” dataset of computer vision. Since its release in 1999, this classic dataset of handwritten images has served as the basis for benchmarking classification algorithms.

# %% [markdown]
# ## Model setup

# %% [markdown]
# Before we start we need to load libraries and setup the model parameters

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})

model_args = {}
# random seed
model_args['seed'] = 123
# we will use batch size of 128 in Stochastic Gradient Descent (SGD) optimization of the network
model_args['batch_size'] = 128 
# learning rate is how fast it will descend
model_args['lr'] = .05
# SGD momentum (default: .5) momentum is a moving average of gradients (it helps to keep direction) 
model_args['momentum'] = .5
# the number of epochs is the number of times you go through the full dataset 
model_args['epochs'] = 50
# logging frequency
model_args['log_interval'] = 100

# %% [markdown]
# Let's start with loading the dataset and check how it looks like
# > **In case of problems with downloading dataset via torchvison please use the second method**

# %%
# load the MINST dataset via torchvision 
transform = transforms.Compose([transforms.ToTensor(), 
                              transforms.Normalize((0.1307,), (0.3081,))])
mnist_train = datasets.MNIST('../data', train=True, download=True, transform=transform)
# we divide this data into training and validation subsets
train_subset, validation_subset = torch.utils.data.random_split(mnist_train, [50000, 10000])
test_subset = datasets.MNIST('../data', train=False, download=True, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw

# %% [markdown]
# Second method: directly download tar.gz archive

# %%
# alternatively just download MNIST.tar.gz archive
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz

transform = transforms.Compose([transforms.ToTensor(), 
                              transforms.Normalize((0.1307,), (0.3081,))])
mnist_train = datasets.MNIST('./', train=True, download=False, transform=transform)
# we divide this data into training and validation subsets
train_subset, validation_subset = torch.utils.data.random_split(mnist_train, [50000, 10000])
test_subset = datasets.MNIST('./', train=False, download=False, transform=transform)
# Out:
# --2023-03-16 19:47:26--  http://www.di.ens.fr/~lelarge/MNIST.tar.gz
# Resolving www.di.ens.fr (www.di.ens.fr)... 129.199.99.14
# Connecting to www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.di.ens.fr/~lelarge/MNIST.tar.gz [following]
# --2023-03-16 19:47:26--  https://www.di.ens.fr/~lelarge/MNIST.tar.gz
# Connecting to www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-gzip]
# Saving to: ‘MNIST.tar.gz’
#
# MNIST.tar.gz            [       <=>          ]  33.20M  26.0MB/s    in 1.3s
#
# 2023-03-16 19:47:27 (26.0 MB/s) - ‘MNIST.tar.gz’ saved [34813078]
#
# MNIST/
# MNIST/raw/
# MNIST/raw/train-labels-idx1-ubyte
# MNIST/raw/t10k-labels-idx1-ubyte.gz
# MNIST/raw/t10k-labels-idx1-ubyte
# MNIST/raw/t10k-images-idx3-ubyte.gz
# MNIST/raw/train-images-idx3-ubyte
# MNIST/raw/train-labels-idx1-ubyte.gz
# MNIST/raw/t10k-images-idx3-ubyte
# MNIST/raw/train-images-idx3-ubyte.gz
# MNIST/processed/
# MNIST/processed/training.pt
# MNIST/processed/test.pt

# %%
# define dataloaders
loader_kwargs = {'batch_size': model_args['batch_size'], 
                 'num_workers': 2, 
                 'pin_memory': True, 
                 'shuffle': True}
train_loader = torch.utils.data.DataLoader(train_subset, **loader_kwargs)
validation_loader = torch.utils.data.DataLoader(validation_subset, **loader_kwargs)
test_loader = torch.utils.data.DataLoader(test_subset, **loader_kwargs)

# %% [markdown]
# Plot sample images

# %%
print(len(train_subset))
print(len(validation_subset))
print(len(test_subset)) # we have data already divided into train & validation & test subsets
print(len(train_loader)) # no of train batches
example_number = 123
print(train_subset[example_number][0][0].shape) # single item shape

fig, axs = plt.subplots(5, 5, figsize=(7,7), tight_layout=True)
for i in range(5):
    for j in range(5):
        axs[i,j].imshow(train_subset[example_number+i*5+j][0].reshape(28,28), cmap='gray')
        axs[i,j].set_title(train_subset[example_number+i*5+j][1])
# Out:
# 50000
# 10000
# 10000
# 391
# torch.Size([28, 28])

# %% [markdown]
# Let's now construct the NN models:
# - we start with siplest single layer **perceptron** with *softmax* activation,
# - then test **deep** network with some (fully-connected) *hidden* layers,
# - and finally setup deep **convolutional neural network**.

# %%
class Perceptron(nn.Module):
    # this defines the structure of the Perceptron model
    def __init__(self):
        super(Perceptron, self).__init__()
        # fully connected layer
        self.fc = nn.Linear(28*28, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc(x)
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

class Deep(nn.Module):
    # this defines the structure of the Perceptron model
    def __init__(self):
        super(Deep, self).__init__()
        # fully connected layers
        self.fc1 = nn.Linear(28*28, 20)
        self.fc2 = nn.Linear(20, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = F.relu(x)
        # hidden layer
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

class CNN(nn.Module):
    # this defines the structure of the CNN model
    def __init__(self):
        super(CNN, self).__init__()
        # convolutional layer with 2 kernels of size 5x5
        self.conv1 = nn.Conv2d(1, 2, kernel_size=5) 
        # 8 kernels of size 5x5
        self.conv2 = nn.Conv2d(2, 4, kernel_size=5)
        # 2D dropout
        self.conv2_drop = nn.Dropout2d()
        # fully connected layers
        self.fc1 = nn.Linear(64, 20)
        self.fc2 = nn.Linear(20, 10)

    def forward(self, x):
        # 1st layers group
        x = self.conv1(x) # resulting in 2 feature maps each of size 24x24
        x = F.max_pool2d(x, 2) # downsizing each map to 12x12
        x = F.relu(x) # standard (in CNNs) ReLU activation
        # 2nd group
        x = self.conv2(x) # resulting in 4 feature maps each of size 8x8
        # x = self.conv2_drop(x) 
        x = F.max_pool2d(x, 2) # downsizing each map to 4x4
        x = F.relu(x)
        # fully connected layers
        x = x.view(-1, 64) # 4 maps of 4x4 size gives 64 numbers
        x = self.fc1(x) # 64 -> 20
        x = F.relu(x)
        x = F.dropout(x, training=self.training) # dropout is a type of regularization
        x = self.fc2(x) # 20 -> 10
        # softmax (multinomial classification) gives probabilities of each class
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

class CNN_v2(nn.Module):
    # this defines the structure of the CNN model
    def __init__(self):
        super(CNN_v2, self).__init__()
        # convolutional layer with 2 kernels of size 5x5
        self.conv1 = nn.Conv2d(1, 20, kernel_size=5) 
        # 20 kernels of size 5x5
        # 2D dropout
        self.conv2_drop = nn.Dropout2d()
        # fully connected layers
        self.fc1 = nn.Linear(720, 360)
        self.fc2 = nn.Linear(360, 180)
        self.fc3 = nn.Linear(180, 90)
        self.fc4 = nn.Linear(90, 10)

    def forward(self, x):
        # 1st layers group
        x = self.conv1(x) # resulting in 2 feature maps each of size 24x24
        x = F.max_pool2d(x, 2) # downsizing each map to 12x12
        x = F.max_pool2d(x, 2) # downsizing each map to 6x6
        x = F.relu(x) # standard (in CNNs) ReLU activation

        # fully connected layers
        x = x.view(-1, 720) # 20 maps of 6x6 size gives 64 numbers
        x = self.fc1(x) # 720 -> 360
        x = F.relu(x)
        x = self.fc2(x) # 360 -> 180
        x = F.relu(x)
        x = self.fc3(x) # 180- -> 90
        x = F.relu(x)
        x = self.fc4(x) # 90 -> 10

        # softmax (multinomial classification) gives probabilities of each class
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

# %% [markdown]
# And define training, testing, and plotting utils:

# %%
def train(model, device, train_loader, optimizer, epoch_number):
    model.train()
    train_loss = 0.
    # get subsequent batches over the data in a given epoch
    for batch_idx, (data, target) in enumerate(train_loader):
        # send data tensors to GPU (or CPU)
        data, target = data.to(device), target.to(device)
        # this will zero out the gradients for this batch
        optimizer.zero_grad()
        # this will execute the forward() function
        output = model(data)
        # calculate the negative-log-likelihood loss
        loss = F.nll_loss(output, target, reduction='mean')
        # backpropagate the loss
        loss.backward()
        # update the model weights (with assumed learning rate)
        optimizer.step()
        if batch_idx % model_args['log_interval'] == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch_number, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
        train_loss += loss.item()
    train_loss /= len(train_loader)
    print('\nTrain set: Average loss: {:.4f}'.format(train_loss))
    return train_loss
    
def test(model, device, test_loader, message):
    model.eval()
    test_loss = 0.
    correct = 0
    # this is just inference, we don't need to calculate gradients
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device) 
            output = model(data)
            # calculate and sum up batch loss
            test_loss += F.nll_loss(output, target, reduction='mean') 
            # get the index of class with the max log-probability 
            prediction = output.argmax(dim=1)  
            # item() returns value of the given tensor
            correct += prediction.eq(target).sum().item()
    test_loss /= len(test_loader)
    print('{}: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        message, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss.cpu()

def plot_loss(train_loss, validation_loss, title):
    plt.grid(True)
    plt.xlabel("subsequent epochs")
    plt.ylabel('average loss')
    plt.plot(range(1, len(train_loss)+1), train_loss, 'o-', label='training')
    plt.plot(range(1, len(validation_loss)+1), validation_loss, 'o-', label='validation')
    plt.legend()
    plt.title(title)
    plt.show()

def conf_matrix(model, device, test_loader, message):
    model.eval()
    test_loss = 0.
    correct = 0
    # this is just inference, we don't need to calculate gradients
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device) 
            output = model(data)
            # calculate and sum up batch loss
            test_loss += F.nll_loss(output, target, reduction='mean') 
            # get the index of class with the max log-probability 
            prediction = output.argmax(dim=1)  
            # item() returns value of the given tensor
            correct += prediction.eq(target).sum().item()
    test_loss /= len(test_loader)
    print('{}: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        message, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss.cpu()

# %% [markdown]
# ## Experiments

# %% [markdown]
# 1. At first let's test the single-layer *Perceptron* model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Perceptron().to(device)

optimizer = optim.SGD(model.parameters(), lr=model_args['lr'], momentum=model_args['momentum'])
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'Perceptron model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.367344
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.335793
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.379339
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.280084
#
# Train set: Average loss: 0.3736
# Validation set: Average loss: 0.3142, Accuracy: 9101/10000 (91%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.197931
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.275867
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.327638
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.208716
#
# Train set: Average loss: 0.3026
# Validation set: Average loss: 0.3086, Accuracy: 9102/10000 (91%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.155380
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.223277
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.295157
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.287577
#
# Train set: Average loss: 0.2898
# Validation set: Average loss: 0.3046, Accuracy: 9155/10000 (92%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.522940
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.209113
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.187450
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.201667
#
# Train set: Average loss: 0.2834
# Validation set: Average loss: 0.2978, Accuracy: 9154/10000 (92%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.335004
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.509303
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.339921
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.356855
#
# Train set: Average loss: 0.2784
# Validation set: Average loss: 0.2965, Accuracy: 9162/10000 (92%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.265909
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.354244
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.281357
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.239887
#
# Train set: Average loss: 0.2746
# Validation set: Average loss: 0.2877, Accuracy: 9199/10000 (92%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.193321
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.134528
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.234650
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.188770
#
# Train set: Average loss: 0.2704
# Validation set: Average loss: 0.2965, Accuracy: 9184/10000 (92%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.329739
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.270916
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.297826
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.188316
#
# Train set: Average loss: 0.2680
# Validation set: Average loss: 0.2936, Accuracy: 9191/10000 (92%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.316954
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.166948
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.235126
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.236188
#
# Train set: Average loss: 0.2659
# Validation set: Average loss: 0.2910, Accuracy: 9185/10000 (92%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.286983
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.201615
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.437794
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.370724
#
# Train set: Average loss: 0.2638
# Validation set: Average loss: 0.2880, Accuracy: 9200/10000 (92%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.288255
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.177545
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.342077
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.272973
#
# Train set: Average loss: 0.2632
# Validation set: Average loss: 0.2949, Accuracy: 9185/10000 (92%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.143373
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.262503
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.184545
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.335534
#
# Train set: Average loss: 0.2619
# Validation set: Average loss: 0.2922, Accuracy: 9213/10000 (92%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.338970
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.177667
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.253600
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.234343
#
# Train set: Average loss: 0.2596
# Validation set: Average loss: 0.2880, Accuracy: 9209/10000 (92%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.193892
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.181814
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.334363
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.289451
#
# Train set: Average loss: 0.2589
# Validation set: Average loss: 0.2953, Accuracy: 9210/10000 (92%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.328375
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.198243
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.250607
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.238160
#
# Train set: Average loss: 0.2574
# Validation set: Average loss: 0.2979, Accuracy: 9197/10000 (92%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.276390
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.227976
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.208177
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.263734
#
# Train set: Average loss: 0.2569
# Validation set: Average loss: 0.2868, Accuracy: 9198/10000 (92%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.256741
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.164646
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.326391
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.362986
#
# Train set: Average loss: 0.2559
# Validation set: Average loss: 0.2943, Accuracy: 9184/10000 (92%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.331732
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.156074
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.235657
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.175417
#
# Train set: Average loss: 0.2543
# Validation set: Average loss: 0.3002, Accuracy: 9161/10000 (92%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.174646
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.361208
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.274454
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.260312
#
# Train set: Average loss: 0.2540
# Validation set: Average loss: 0.3016, Accuracy: 9165/10000 (92%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.236201
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.334283
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.313637
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.356919
#
# Train set: Average loss: 0.2533
# Validation set: Average loss: 0.2958, Accuracy: 9184/10000 (92%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.354202
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.239915
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.202610
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.148890
#
# Train set: Average loss: 0.2515
# Validation set: Average loss: 0.2900, Accuracy: 9209/10000 (92%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.178192
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.208572
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.397408
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.165395
#
# Train set: Average loss: 0.2520
# Validation set: Average loss: 0.2931, Accuracy: 9217/10000 (92%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.279906
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.126655
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.444985
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.226107
#
# Train set: Average loss: 0.2512
# Validation set: Average loss: 0.2928, Accuracy: 9183/10000 (92%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.193793
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.270453
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.224845
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.303082
#
# Train set: Average loss: 0.2502
# Validation set: Average loss: 0.3025, Accuracy: 9185/10000 (92%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.279018
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.224409
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.382068
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.216679
#
# Train set: Average loss: 0.2502
# Validation set: Average loss: 0.2918, Accuracy: 9234/10000 (92%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.223373
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.221165
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.298601
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.098629
#
# Train set: Average loss: 0.2490
# Validation set: Average loss: 0.2947, Accuracy: 9212/10000 (92%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.255731
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.200229
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.176070
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.453011
#
# Train set: Average loss: 0.2487
# Validation set: Average loss: 0.2885, Accuracy: 9220/10000 (92%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.177456
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.176496
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.339325
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.215448
#
# Train set: Average loss: 0.2483
# Validation set: Average loss: 0.2940, Accuracy: 9183/10000 (92%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.116555
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.117301
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.317344
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.354093
#
# Train set: Average loss: 0.2481
# Validation set: Average loss: 0.2979, Accuracy: 9199/10000 (92%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.175773
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.197676
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.213988
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.210302
#
# Train set: Average loss: 0.2475
# Validation set: Average loss: 0.2965, Accuracy: 9233/10000 (92%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.196327
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.198338
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.334191
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.188672
#
# Train set: Average loss: 0.2468
# Validation set: Average loss: 0.2938, Accuracy: 9217/10000 (92%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.328754
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.318825
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.429694
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.235361
#
# Train set: Average loss: 0.2465
# Validation set: Average loss: 0.2921, Accuracy: 9229/10000 (92%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.226230
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.281735
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.429950
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.153731
#
# Train set: Average loss: 0.2462
# Validation set: Average loss: 0.3084, Accuracy: 9173/10000 (92%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.257068
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.339023
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.239777
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.185468
#
# Train set: Average loss: 0.2459
# Validation set: Average loss: 0.2998, Accuracy: 9192/10000 (92%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.275210
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.306582
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.207130
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.302058
#
# Train set: Average loss: 0.2458
# Validation set: Average loss: 0.3022, Accuracy: 9208/10000 (92%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.409933
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.160023
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.312184
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.266296
#
# Train set: Average loss: 0.2451
# Validation set: Average loss: 0.2943, Accuracy: 9209/10000 (92%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.259533
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.236131
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.176847
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.328170
#
# Train set: Average loss: 0.2436
# Validation set: Average loss: 0.2939, Accuracy: 9222/10000 (92%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.192100
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.160870
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.182996
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.297108
#
# Train set: Average loss: 0.2436
# Validation set: Average loss: 0.2919, Accuracy: 9213/10000 (92%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.272529
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.092862
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.161143
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.264566
#
# Train set: Average loss: 0.2431
# Validation set: Average loss: 0.3023, Accuracy: 9209/10000 (92%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.277152
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.163019
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.162516
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.156819
#
# Train set: Average loss: 0.2433
# Validation set: Average loss: 0.2948, Accuracy: 9211/10000 (92%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.385017
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.509103
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.298685
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.171082
#
# Train set: Average loss: 0.2430
# Validation set: Average loss: 0.2951, Accuracy: 9201/10000 (92%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.287091
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.218457
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.208692
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.189439
#
# Train set: Average loss: 0.2436
# Validation set: Average loss: 0.2989, Accuracy: 9206/10000 (92%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.156100
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.240608
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.175208
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.222665
#
# Train set: Average loss: 0.2425
# Validation set: Average loss: 0.3126, Accuracy: 9154/10000 (92%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.308920
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.286329
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.260464
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.186318
#
# Train set: Average loss: 0.2421
# Validation set: Average loss: 0.2996, Accuracy: 9206/10000 (92%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.382422
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.269724
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.256191
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.238910
#
# Train set: Average loss: 0.2420
# Validation set: Average loss: 0.2975, Accuracy: 9203/10000 (92%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.091594
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.270006
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.392848
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.210827
#
# Train set: Average loss: 0.2422
# Validation set: Average loss: 0.2997, Accuracy: 9202/10000 (92%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.325095
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.435347
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.322849
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.163981
#
# Train set: Average loss: 0.2415
# Validation set: Average loss: 0.2980, Accuracy: 9213/10000 (92%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.155687
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.177765
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.170441
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.249371
#
# Train set: Average loss: 0.2416
# Validation set: Average loss: 0.2942, Accuracy: 9206/10000 (92%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.329140
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.432324
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.215247
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.204527
#
# Train set: Average loss: 0.2417
# Validation set: Average loss: 0.3029, Accuracy: 9200/10000 (92%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.178278
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.192402
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.330432
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.159729
#
# Train set: Average loss: 0.2407
# Validation set: Average loss: 0.3065, Accuracy: 9148/10000 (91%)
#
# Test set: Average loss: 0.2966, Accuracy: 9175/10000 (92%)

# %% [markdown]
# 2. Now add a hidden layer to the *Perceptron* and evaluate the *Deep* model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Deep().to(device)

optimizer = optim.SGD(model.parameters(), 
                      lr=model_args['lr'], 
                      momentum=model_args['momentum'])
                      #weight_decay=1.e-3)
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'Deep model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.379309
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.358160
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.364938
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.227584
#
# Train set: Average loss: 0.4193
# Validation set: Average loss: 0.2794, Accuracy: 9171/10000 (92%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.212295
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.229705
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.242325
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.136544
#
# Train set: Average loss: 0.2483
# Validation set: Average loss: 0.2339, Accuracy: 9314/10000 (93%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.117815
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.147564
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.196541
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.172402
#
# Train set: Average loss: 0.2020
# Validation set: Average loss: 0.2019, Accuracy: 9409/10000 (94%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.355064
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.136823
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.139137
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.096722
#
# Train set: Average loss: 0.1755
# Validation set: Average loss: 0.1896, Accuracy: 9432/10000 (94%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.215960
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.321410
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.145023
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.209154
#
# Train set: Average loss: 0.1578
# Validation set: Average loss: 0.1843, Accuracy: 9457/10000 (95%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.095961
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.206470
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.120100
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.182294
#
# Train set: Average loss: 0.1450
# Validation set: Average loss: 0.1708, Accuracy: 9492/10000 (95%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.159023
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.049895
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.112560
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.070522
#
# Train set: Average loss: 0.1359
# Validation set: Average loss: 0.1755, Accuracy: 9515/10000 (95%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.135812
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.060344
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.194082
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.095391
#
# Train set: Average loss: 0.1274
# Validation set: Average loss: 0.1608, Accuracy: 9531/10000 (95%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.148418
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.131627
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.121216
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.112196
#
# Train set: Average loss: 0.1224
# Validation set: Average loss: 0.1577, Accuracy: 9542/10000 (95%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.041593
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.117913
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.237464
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.134004
#
# Train set: Average loss: 0.1156
# Validation set: Average loss: 0.1536, Accuracy: 9555/10000 (96%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.110317
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.090455
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.120067
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.069434
#
# Train set: Average loss: 0.1118
# Validation set: Average loss: 0.1613, Accuracy: 9532/10000 (95%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.036729
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.088448
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.072088
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.173631
#
# Train set: Average loss: 0.1086
# Validation set: Average loss: 0.1651, Accuracy: 9544/10000 (95%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.150520
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.052157
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.091321
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.030621
#
# Train set: Average loss: 0.1034
# Validation set: Average loss: 0.1563, Accuracy: 9547/10000 (95%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.089152
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.062894
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.097463
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.069392
#
# Train set: Average loss: 0.1009
# Validation set: Average loss: 0.1607, Accuracy: 9567/10000 (96%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.074653
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.090595
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.079826
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.078853
#
# Train set: Average loss: 0.0985
# Validation set: Average loss: 0.1684, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.095468
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.073510
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.065430
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.078105
#
# Train set: Average loss: 0.0957
# Validation set: Average loss: 0.1580, Accuracy: 9555/10000 (96%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.070795
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.071058
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.079782
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.130351
#
# Train set: Average loss: 0.0930
# Validation set: Average loss: 0.1679, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.135813
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.034528
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.057428
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.045441
#
# Train set: Average loss: 0.0912
# Validation set: Average loss: 0.1767, Accuracy: 9527/10000 (95%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.069144
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.134139
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.080353
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.047142
#
# Train set: Average loss: 0.0881
# Validation set: Average loss: 0.1789, Accuracy: 9523/10000 (95%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.062767
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.099594
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.036063
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.159996
#
# Train set: Average loss: 0.0867
# Validation set: Average loss: 0.1607, Accuracy: 9588/10000 (96%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.132030
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.152071
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.033851
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.067250
#
# Train set: Average loss: 0.0845
# Validation set: Average loss: 0.1768, Accuracy: 9516/10000 (95%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.044517
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.063970
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.137657
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.032749
#
# Train set: Average loss: 0.0838
# Validation set: Average loss: 0.1670, Accuracy: 9553/10000 (96%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.063348
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.014570
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.089339
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.073630
#
# Train set: Average loss: 0.0823
# Validation set: Average loss: 0.1693, Accuracy: 9570/10000 (96%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.078624
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.074940
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.036203
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.073584
#
# Train set: Average loss: 0.0796
# Validation set: Average loss: 0.1772, Accuracy: 9533/10000 (95%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.107588
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.062695
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.075878
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.057625
#
# Train set: Average loss: 0.0782
# Validation set: Average loss: 0.1633, Accuracy: 9552/10000 (96%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.047176
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.051116
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.068293
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.021918
#
# Train set: Average loss: 0.0777
# Validation set: Average loss: 0.1754, Accuracy: 9561/10000 (96%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.037598
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.042797
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.118337
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.060142
#
# Train set: Average loss: 0.0749
# Validation set: Average loss: 0.1704, Accuracy: 9558/10000 (96%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.039274
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.057500
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.128360
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.095776
#
# Train set: Average loss: 0.0738
# Validation set: Average loss: 0.1910, Accuracy: 9505/10000 (95%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.058658
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.058170
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.079189
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.201682
#
# Train set: Average loss: 0.0736
# Validation set: Average loss: 0.1738, Accuracy: 9552/10000 (96%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.032099
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.060448
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.025733
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.082459
#
# Train set: Average loss: 0.0723
# Validation set: Average loss: 0.1733, Accuracy: 9545/10000 (95%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.046571
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.042359
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.090852
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.044007
#
# Train set: Average loss: 0.0708
# Validation set: Average loss: 0.1776, Accuracy: 9552/10000 (96%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.049093
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.224442
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.147566
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.066089
#
# Train set: Average loss: 0.0705
# Validation set: Average loss: 0.1871, Accuracy: 9551/10000 (96%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.074519
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.120048
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.141090
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.081382
#
# Train set: Average loss: 0.0694
# Validation set: Average loss: 0.1789, Accuracy: 9564/10000 (96%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.126420
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.145301
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.033243
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.051481
#
# Train set: Average loss: 0.0671
# Validation set: Average loss: 0.1819, Accuracy: 9551/10000 (96%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.085197
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.039627
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.030740
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.070838
#
# Train set: Average loss: 0.0667
# Validation set: Average loss: 0.1960, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.130508
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.064158
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.105839
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.068396
#
# Train set: Average loss: 0.0651
# Validation set: Average loss: 0.1847, Accuracy: 9539/10000 (95%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.034340
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.061739
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.030073
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.183511
#
# Train set: Average loss: 0.0644
# Validation set: Average loss: 0.1844, Accuracy: 9551/10000 (96%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.042141
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.031879
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.019848
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.104941
#
# Train set: Average loss: 0.0631
# Validation set: Average loss: 0.1900, Accuracy: 9546/10000 (95%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.051751
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.027934
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.022379
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.091763
#
# Train set: Average loss: 0.0625
# Validation set: Average loss: 0.1954, Accuracy: 9527/10000 (95%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.039442
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.042512
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.024846
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.055036
#
# Train set: Average loss: 0.0618
# Validation set: Average loss: 0.1901, Accuracy: 9551/10000 (96%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.076667
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.134219
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.079744
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.041934
#
# Train set: Average loss: 0.0609
# Validation set: Average loss: 0.1972, Accuracy: 9534/10000 (95%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.073239
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.132971
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.025267
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.043970
#
# Train set: Average loss: 0.0595
# Validation set: Average loss: 0.1962, Accuracy: 9554/10000 (96%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.021680
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.034964
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.039187
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.073271
#
# Train set: Average loss: 0.0602
# Validation set: Average loss: 0.2020, Accuracy: 9519/10000 (95%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.121159
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.082497
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.025648
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.019598
#
# Train set: Average loss: 0.0583
# Validation set: Average loss: 0.2018, Accuracy: 9538/10000 (95%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.087707
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.061035
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.045571
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.088536
#
# Train set: Average loss: 0.0562
# Validation set: Average loss: 0.1996, Accuracy: 9539/10000 (95%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.005101
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.072967
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.060673
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.098625
#
# Train set: Average loss: 0.0567
# Validation set: Average loss: 0.2066, Accuracy: 9523/10000 (95%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.086073
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.118999
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.097331
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.053942
#
# Train set: Average loss: 0.0553
# Validation set: Average loss: 0.2081, Accuracy: 9507/10000 (95%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.023487
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.033767
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.036480
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.056884
#
# Train set: Average loss: 0.0561
# Validation set: Average loss: 0.2058, Accuracy: 9534/10000 (95%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.076758
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.042250
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.013319
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.055457
#
# Train set: Average loss: 0.0544
# Validation set: Average loss: 0.2043, Accuracy: 9524/10000 (95%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.055401
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.045154
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.043565
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.012501
#
# Train set: Average loss: 0.0528
# Validation set: Average loss: 0.2230, Accuracy: 9506/10000 (95%)
#
# Test set: Average loss: 0.2071, Accuracy: 9490/10000 (95%)

# %% [markdown]
# 3. Compare these results with a deep convolutional network, which is more useful in real-world problems:

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CNN().to(device)

optimizer = optim.SGD(model.parameters(), lr=model_args['lr'], momentum=model_args['momentum'])
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'CNN model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.299129
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.242865
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.915733
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.744278
#
# Train set: Average loss: 1.1614
# Validation set: Average loss: 0.3547, Accuracy: 8919/10000 (89%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.831336
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.686484
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.839380
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.630056
#
# Train set: Average loss: 0.6911
# Validation set: Average loss: 0.2512, Accuracy: 9286/10000 (93%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.536730
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.495992

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CNN_v2().to(device)

optimizer = optim.SGD(model.parameters(), lr=model_args['lr'], momentum=model_args['momentum'],nesterov=True)
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'CNN model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.312516
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.132750
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.252156
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.130010
#
# Train set: Average loss: 0.5482
# Validation set: Average loss: 0.1398, Accuracy: 9569/10000 (96%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.071903
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.085773
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.108629
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.061143
#
# Train set: Average loss: 0.0918
# Validation set: Average loss: 0.2299, Accuracy: 9208/10000 (92%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.269019
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.023887
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.044391
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.105084
#
# Train set: Average loss: 0.0644
# Validation set: Average loss: 0.0642, Accuracy: 9799/10000 (98%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.053666
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.029320
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.044553
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.024302
#
# Train set: Average loss: 0.0491
# Validation set: Average loss: 0.0441, Accuracy: 9856/10000 (99%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.020872
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.021189
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.065487
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.027863
#
# Train set: Average loss: 0.0396
# Validation set: Average loss: 0.0577, Accuracy: 9811/10000 (98%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.039099
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.051184
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.109322
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.032766
#
# Train set: Average loss: 0.0345
# Validation set: Average loss: 0.0390, Accuracy: 9878/10000 (99%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.020085
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.014778
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.001784
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.054410
#
# Train set: Average loss: 0.0276
# Validation set: Average loss: 0.0358, Accuracy: 9866/10000 (99%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.011222
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.008924
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.009572
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.008075
#
# Train set: Average loss: 0.0226
# Validation set: Average loss: 0.0659, Accuracy: 9786/10000 (98%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.049759
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.027300
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.012709
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.008214
#
# Train set: Average loss: 0.0213
# Validation set: Average loss: 0.0497, Accuracy: 9830/10000 (98%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.053138
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.004942
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.026057
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.024252
#
# Train set: Average loss: 0.0170
# Validation set: Average loss: 0.0427, Accuracy: 9875/10000 (99%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.053872
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.000636
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.007658
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.007337
#
# Train set: Average loss: 0.0147
# Validation set: Average loss: 0.0311, Accuracy: 9901/10000 (99%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.006684
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.007260
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.013208
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.009161
#
# Train set: Average loss: 0.0132
# Validation set: Average loss: 0.0300, Accuracy: 9906/10000 (99%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.005759
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.015388
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.009892
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.001019
#
# Train set: Average loss: 0.0104
# Validation set: Average loss: 0.0353, Accuracy: 9899/10000 (99%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.003427
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.011145
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.001190
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.006095
#
# Train set: Average loss: 0.0087
# Validation set: Average loss: 0.0362, Accuracy: 9898/10000 (99%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.002351
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.000732
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.000832
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.023130
#
# Train set: Average loss: 0.0087
# Validation set: Average loss: 0.0319, Accuracy: 9903/10000 (99%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.002589
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.000159
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.008669
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.002299
#
# Train set: Average loss: 0.0073
# Validation set: Average loss: 0.0308, Accuracy: 9905/10000 (99%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.000210
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.004111
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.010426
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.003174
#
# Train set: Average loss: 0.0069
# Validation set: Average loss: 0.0345, Accuracy: 9899/10000 (99%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.023398
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.004093
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.000387
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.003136
#
# Train set: Average loss: 0.0046
# Validation set: Average loss: 0.0313, Accuracy: 9913/10000 (99%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.001324
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.002420
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.000184
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.000367
#
# Train set: Average loss: 0.0033
# Validation set: Average loss: 0.0313, Accuracy: 9910/10000 (99%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.003667
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.000819
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.003732
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.001857
#
# Train set: Average loss: 0.0027
# Validation set: Average loss: 0.0334, Accuracy: 9912/10000 (99%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.001288
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.000243
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.000438
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.005839
#
# Train set: Average loss: 0.0025
# Validation set: Average loss: 0.0308, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.000701
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.000333
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.001691
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.003004
#
# Train set: Average loss: 0.0019
# Validation set: Average loss: 0.0312, Accuracy: 9913/10000 (99%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.000591
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.000115
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.015241
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.000107
#
# Train set: Average loss: 0.0013
# Validation set: Average loss: 0.0340, Accuracy: 9908/10000 (99%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.000198
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.000278
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.000244
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.001602
#
# Train set: Average loss: 0.0011
# Validation set: Average loss: 0.0330, Accuracy: 9909/10000 (99%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.000553
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.000176
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.000888
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.000379
#
# Train set: Average loss: 0.0012
# Validation set: Average loss: 0.0356, Accuracy: 9905/10000 (99%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.000088
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.000152
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.000128
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.000378
#
# Train set: Average loss: 0.0009
# Validation set: Average loss: 0.0335, Accuracy: 9917/10000 (99%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.001348
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.000165
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.001705
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.000175
#
# Train set: Average loss: 0.0007
# Validation set: Average loss: 0.0345, Accuracy: 9917/10000 (99%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.000528
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.000347
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.000276
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.000107
#
# Train set: Average loss: 0.0008
# Validation set: Average loss: 0.0381, Accuracy: 9903/10000 (99%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.001108
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.000335
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.000076
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.000041
#
# Train set: Average loss: 0.0007
# Validation set: Average loss: 0.0356, Accuracy: 9908/10000 (99%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.000389
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.000314
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.000738
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.006771
#
# Train set: Average loss: 0.0005
# Validation set: Average loss: 0.0346, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.000310
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.000048
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.000218
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.000494
#
# Train set: Average loss: 0.0005
# Validation set: Average loss: 0.0363, Accuracy: 9909/10000 (99%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.000337
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.000175
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.000242
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.000067
#
# Train set: Average loss: 0.0003
# Validation set: Average loss: 0.0351, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.000027
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.000059
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.000949
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.000196
#
# Train set: Average loss: 0.0003
# Validation set: Average loss: 0.0356, Accuracy: 9918/10000 (99%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.000092
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.000088
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.000062
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.000883
#
# Train set: Average loss: 0.0003
# Validation set: Average loss: 0.0363, Accuracy: 9917/10000 (99%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.000057
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.000161
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.000111
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.000296
#
# Train set: Average loss: 0.0002
# Validation set: Average loss: 0.0357, Accuracy: 9917/10000 (99%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.000254
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.000064
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.000059
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.000012
#
# Train set: Average loss: 0.0002
# Validation set: Average loss: 0.0368, Accuracy: 9912/10000 (99%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.000009
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.000142
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.000239
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.000072
#
# Train set: Average loss: 0.0002
# Validation set: Average loss: 0.0371, Accuracy: 9913/10000 (99%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.000241
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.000363
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.000047
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.000007
#
# Train set: Average loss: 0.0002
# Validation set: Average loss: 0.0376, Accuracy: 9909/10000 (99%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.000096
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.000253
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.000066
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.000098
#
# Train set: Average loss: 0.0002
# Validation set: Average loss: 0.0395, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.000082
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.000119
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.000049
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.000289
#
# Train set: Average loss: 0.0002
# Validation set: Average loss: 0.0380, Accuracy: 9911/10000 (99%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.000046
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.000069
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.000093
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.000039
#
# Train set: Average loss: 0.0002
# Validation set: Average loss: 0.0384, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.000001
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.000259
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.000098
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.000106
#
# Train set: Average loss: 0.0001
# Validation set: Average loss: 0.0382, Accuracy: 9913/10000 (99%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.000057
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.000034
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.000007
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.000115
#
# Train set: Average loss: 0.0001
# Validation set: Average loss: 0.0378, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.000041
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.000041
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.000413
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.000035
#
# Train set: Average loss: 0.0001
# Validation set: Average loss: 0.0378, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.000278
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.000108
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.000180
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.000007
#
# Train set: Average loss: 0.0001
# Validation set: Average loss: 0.0383, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.000115
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.000049
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.000096
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.000095
#
# Train set: Average loss: 0.0001
# Validation set: Average loss: 0.0387, Accuracy: 9914/10000 (99%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.000137
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.000052
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.000003
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.000025
#
# Train set: Average loss: 0.0001
# Validation set: Average loss: 0.0389, Accuracy: 9913/10000 (99%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.000114
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.000211
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.000118
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.000107
#
# Train set: Average loss: 0.0001
# Validation set: Average loss: 0.0392, Accuracy: 9916/10000 (99%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.000095
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.000062
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.000012
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.000022
#
# Train set: Average loss: 0.0001
# Validation set: Average loss: 0.0405, Accuracy: 9915/10000 (99%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.000167
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.000074
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.000084
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.000064
#
# Train set: Average loss: 0.0001
# Validation set: Average loss: 0.0388, Accuracy: 9913/10000 (99%)
#
# Test set: Average loss: 0.0364, Accuracy: 9902/10000 (99%)

# %% [markdown]
# ## Summary
# * *Deep* and *CNN* models with accuracies of 96% and 97% (evaluated on the test subset) perform much better than single-layer *Perceptron* with 92%;
# * The two smallest (and simplest) models appear to be overfitted. To deal with this we need to apply some regularization.
# * Validation subset is evaluated during the training (as opposed to test set, infered *after* the training) in order to tune the model hiperparameters (that describe e.g. the network structure, or training details).
# * A moment to stop trainning is a kind of hipermarameter -- by applying *early stopping* we can avoid overfitting.

# %% [markdown]
# ## Tasks to do
# * apply some regularization technique to *Deep* model in order to avoid overfitting (start with nonzero *weight_decay* in optimizer)
# * try to figure out why the validation loss for *CNN* model turns to be *lower* than the train loss (hint: turn off regularization),
# * **tune one of these models to get the *Test Set Accuracy* > 99%**,
# * plot the *confusion matrix* among all of the classes---which of digits are mostly confused with each other?
# >How to build the confusion matrix?
# > * for example 1st row represents images with "0" digit (*ground truth*), while 1st colum images for which the model *predicts* "0",
# > * this way element _11 is equal to number of images with "0" corectly clasified as "0" (true positives), while _15 number of images with "0" wrongly calssified as "4", and so on.
# * and finally prepare report.
#
# ### How the report should look like
# * 1-2 page long
# * shortly describe what modifications you apply
# * justyfy in a few words why your improved model is so cool
# * results should be presented as plots with multiline captions
