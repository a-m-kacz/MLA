# %% [markdown]
# <a href="https://colab.research.google.com/github/a-m-kacz/MLA/blob/main/v2_lab4_regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reguralization in CNN networks
# - we are going to compare various approaches to regularizarion in neural networks,
# - we will use standard image classification task with CNN networks.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models

import numpy as np

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})

model_args = {}
# we will use batch size of 64 in Stochastic Gradient Descent (SGD) optimization of the network
model_args['batch_size'] = 64 
# learning rate is how fast it will descend
model_args['lr'] = .07
# the number of epochs is the number of times you go through the full dataset
model_args['epochs'] = 30
# L2 (ridge) penalty
model_args['L2_lambda'] = 5.e-3
# L1 (LASSO) penalty
model_args['L1_lambda'] = 2.e-4

# %% [markdown]
# ### Define problem
# - we are going to use CIFAR-10 [dataset](https://www.cs.toronto.edu/~kriz/cifar.html) of 32x32 color images to train image classifier,
# - in order to test various regularizations our vanilla CNN classifier should be overfitted.

# %% [markdown]
# ### Download the dataset

# %%
# !rm -r ./data
# normalize dataset
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean, std)])

cifar10_train = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# we divide this data into training and validation subsets
train_subset, validation_subset = torch.utils.data.random_split(cifar10_train, [40000, 10000])
test_subset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# subsample to speedup training (colab has notebook lifetime limit)
train_subset = torch.utils.data.Subset(train_subset, range(20000))
validation_subset = torch.utils.data.Subset(validation_subset, range(5000))
test_subset = torch.utils.data.Subset(test_subset, range(5000))

# define dataloaders
loader_kwargs = {'batch_size': model_args['batch_size'], 
                 'num_workers': 2, 
                 'pin_memory': True, 
                 'shuffle': True}
train_loader = torch.utils.data.DataLoader(train_subset, **loader_kwargs)
validation_loader = torch.utils.data.DataLoader(validation_subset, **loader_kwargs)
test_loader = torch.utils.data.DataLoader(test_subset, **loader_kwargs)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# rm: cannot remove './data': No such file or directory
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:05<00:00, 29270306.46it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ### Define CNN models and util methods
# - (over)simpified CNN
# - VGG11 (definition borrowed from *https://github.com/chengyangfu/pytorch-vgg-cifar10*)

# %%
class SimpleCNN(nn.Module):
    '''
    simple CNN model
    '''
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 80)
        self.fc3 = nn.Linear(80, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


class VGG(nn.Module):
    '''
    VGG model 
    '''
    def __init__(self, features):
        super(VGG, self).__init__()
        self.features = features
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(512, 512),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(512, 512),
            nn.ReLU(True),
            nn.Linear(512, 10),
        )
        # Initialize weights
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, np.sqrt(2. / n))
                m.bias.data.zero_()

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

def make_layers(cfg, batch_norm=False):
    layers = []
    in_channels = 3
    for v in cfg:
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)

vgg_cfg = {
    'vgg11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'vgg13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'vgg16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'vgg19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
    'vgg22': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 256, 'M', 512, 512, 512, 512, 512, 'M', 512, 512, 512, 512, 512, 'M']
}


def train_with_regularization(model, device, train_loader, optimizer, criterion, 
                              epoch_number, 
                              L1_lambda, 
                              L2_lambda):
    model.train()
    train_loss = 0.
    # get subsequent batches over the data in a given epoch
    for batch_idx, (data, target) in enumerate(train_loader):
        # send data tensors to GPU (or CPU)
        data, target = data.to(device), target.to(device)
        # this will zero out the gradients for this batch
        optimizer.zero_grad()
        # this will execute the forward() function
        output = model(data)
        # calculate loss using c
        loss = criterion(output, target)
        # L2 regularization implemeted by hand
        L2_norm = sum((p**2).sum() for p in model.parameters())
        # L1 regularization
        L1_norm = sum(p.abs().sum() for p in model.parameters())
        #
        loss_regularized = loss + L1_norm*L1_lambda + L2_norm*L2_lambda
        # backpropagate the loss
        loss_regularized.backward()
        # update the model weights (with assumed learning rate)
        optimizer.step()
        train_loss += loss.item()
    print('Train Epoch: {}'.format(epoch_number))
    train_loss /= len(train_loader)
    print('\tTrain set: Average loss: {:.4f}'.format(train_loss))
    return train_loss
    
def test(model, device, test_loader, criterion, message=None):
    model.eval()
    test_loss = 0.
    correct = 0
    # this is just inference, we don't need to calculate gradients
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device) 
            output = model(data)
            # calculate and sum up batch loss
            test_loss += criterion(output, target) 
            # get the index of class with the max probability 
            prediction = output.argmax(dim=1)  
            #_, predicted = torch.max(outputs.data, axis=1)
            # item() returns value of the given tensor
            correct += prediction.eq(target).sum().item()
    test_loss /= len(test_loader)
    accuracy = correct / len(test_loader.dataset)
    if message is not None:
        print('\t{}: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
            message, test_loss, correct, len(test_loader.dataset), 100.*accuracy))
    return test_loss.cpu(), accuracy

def run_training(model, device, criterion, optimizer, no_epochs,
                 L1_lambda=0., 
                 L2_lambda=0.):
    train_loss = []
    validation_loss = []
    validation_accuracy = []
    test_accuracy = []
    for epoch_number in range(1, no_epochs+1):
        train_loss.append(train_with_regularization(model, device, train_loader, 
                                optimizer, criterion, epoch_number,
                                L1_lambda, L2_lambda))
        val_loss, val_acc = test(model, device, validation_loader, 
                                criterion, 'Validation set')
        validation_loss.append(val_loss)
        validation_accuracy.append(val_acc)
        # we also collect test accuracies for every epoch
        _, test_acc = test(model, device, test_loader, criterion)
        test_accuracy.append(test_acc)
    # and select test accuracy for the best epoch (with the highest validation accuracy)
    best_accuracy = test_accuracy[np.argmax(validation_accuracy)]
    return train_loss, validation_loss, best_accuracy

def plot_loss(train_loss, validation_loss, title):
    plt.grid(True)
    plt.xlabel("subsequent epochs")
    plt.ylabel('average loss')
    plt.plot(range(1, len(train_loss)+1), train_loss, 'o-', label='training')
    plt.plot(range(1, len(validation_loss)+1), validation_loss, 'o-', label='validation')
    plt.legend()
    plt.title(title)
    plt.show()

# %% [markdown]
# # 0. Try to play with L2 and L1 *lambdas* do get highest possible accuracy.
# - e.g. what if we increase *L1_lambda* to be the same as *L2_lambda*

# %% [markdown]
# # nazwy plikow sie powtarzajac zmienic loss na loss

# %% [markdown]
# ## -> there is a code for extracting weights below
# ## -> what shape is model_0_params after training

# %%
def plot_and_save_weights(model_params,name,bins=100):
  weights = np.concatenate([p.flatten() for p in model_params])
  np.savetxt(name+".txt",weights)
  # Plot histogram of weights
  plt.hist(weights, bins=bins)
  plt.title(name)
  plt.xlabel('Weight values')
  plt.ylabel('Frequency')
  plt.title('Histogram of model weights')

# %% [markdown]
# ### Do the experiments
# - without any regularization
# - *weigt_decay*, L2 regularization implemeted in optimizer, e.g. Adam or SGD as here: see [discussion](https://discuss.pytorch.org/t/how-does-sgd-weight-decay-work/33105/6)
# - L2 and L1 regularization implemeted by hand

# %%
CNN_results_dict = {}
CNN_results_dict["without"]={}
CNN_results_dict["weight decay"]={}
CNN_results_dict["L1"]={}
CNN_results_dict["L2"]={}
CNN_results_dict["L2=L1"]={}

VGG_results_dict = {}
VGG_results_dict["without"]={}
VGG_results_dict["weight decay"]={}
VGG_results_dict["L1"]={}
VGG_results_dict["L2"]={}
VGG_results_dict["L2=L1"]={}

# %% [markdown]
# Simple CNN Without

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = SimpleCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), 
                      lr=model_args['lr'],
                      weight_decay=0.)

train_loss_0, val_loss_0, best_accuracy = run_training(model, device, criterion, optimizer, model_args['epochs'])

print('\nTest accuracy for best epoch: {:.0f}%\n'.format(100.*best_accuracy))
plot_loss(train_loss_0, val_loss_0, 'Simple CNN Without any regularization')
model_0_params = [p.detach().cpu().numpy() for p in model.parameters()]


CNN_results_dict["without"]["train loss"] = train_loss_0
CNN_results_dict["without"]["val loss"] = val_loss_0
CNN_results_dict["without"]["best accuracy"] = best_accuracy
CNN_results_dict["without"]["weights"] = np.concatenate([p.flatten() for p in model_0_params])

# %% [markdown]
# VGG without

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = VGG(make_layers(vgg_cfg['vgg11'])).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), 
                      lr=model_args['lr'],
                      weight_decay=0.)

train_loss_0, val_loss_0, best_accuracy = run_training(model, device, criterion, optimizer, model_args['epochs'])

print('\nTest accuracy for best epoch: {:.0f}%\n'.format(100.*best_accuracy))
plot_loss(train_loss_0, val_loss_0, 'VGG11 Without any regularization')
model_0_params = [p.detach().cpu().numpy() for p in model.parameters()]

VGG_results_dict["without"]["train loss"] = train_loss_0
VGG_results_dict["without"]["val loss"] = val_loss_0
VGG_results_dict["without"]["best accuracy"] = best_accuracy
VGG_results_dict["without"]["weights"] = np.concatenate([p.flatten() for p in model_0_params])
# Out:
# Train Epoch: 1
# 	Train set: Average loss: 2.2172
# 	Validation set: Average loss: 2.0035, Accuracy: 1081/5000 (22%)
# Train Epoch: 2
# 	Train set: Average loss: 1.9136
# 	Validation set: Average loss: 1.8144, Accuracy: 1553/5000 (31%)
# Train Epoch: 3
# 	Train set: Average loss: 1.7118
# 	Validation set: Average loss: 1.6926, Accuracy: 1753/5000 (35%)
# Train Epoch: 4
# 	Train set: Average loss: 1.5485
# 	Validation set: Average loss: 1.6560, Accuracy: 2035/5000 (41%)
# Train Epoch: 5
# 	Train set: Average loss: 1.4108
# 	Validation set: Average loss: 1.3818, Accuracy: 2443/5000 (49%)
# Train Epoch: 6
# 	Train set: Average loss: 1.2801
# 	Validation set: Average loss: 1.3500, Accuracy: 2554/5000 (51%)
# Train Epoch: 7
# 	Train set: Average loss: 1.1501
# 	Validation set: Average loss: 1.2578, Accuracy: 2739/5000 (55%)
# Train Epoch: 8
# 	Train set: Average loss: 1.0159
# 	Validation set: Average loss: 1.0978, Accuracy: 3028/5000 (61%)
# Train Epoch: 9
# 	Train set: Average loss: 0.8979
# 	Validation set: Average loss: 1.4163, Accuracy: 2619/5000 (52%)
# Train Epoch: 10
print('\nTest accuracy for best epoch: {:.0f}%\n'.format(100.*best_accuracy))
plot_loss(train_loss_wd, val_loss_wd, 'Simple CNN SGD weight_decay used')
model_wd_params = [p.detach().cpu().numpy() for p in model.parameters()]

CNN_results_dict["weight decay"]["train loss"] = train_loss_wd
CNN_results_dict["weight decay"]["val loss"] = val_loss_wd
CNN_results_dict["weight decay"]["best accuracy"] = best_accuracy
CNN_results_dict["weight decay"]["weights"] = np.concatenate([p.flatten() for p in model_wd_params])

# %% [markdown]
# VGG11 weight decay

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = VGG(make_layers(vgg_cfg['vgg11'])).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), 
                      lr=model_args['lr'],
                      weight_decay=5.e-4)

train_loss_wd, val_loss_wd, best_accuracy = run_training(model, device, criterion, optimizer, model_args['epochs'])

print('\nTest accuracy for best epoch: {:.0f}%\n'.format(100.*best_accuracy))
plot_loss(train_loss_wd, val_loss_wd, 'VGG11 SGD weight_decay used')
model_VGGwd_params = [p.detach().cpu().numpy() for p in model.parameters()]

VGG_results_dict["weight decay"]["train loss"] = train_loss_wd
VGG_results_dict["weight decay"]["val loss"] = val_loss_wd
VGG_results_dict["weight decay"]["best accuracy"] = best_accuracy
VGG_results_dict["weight decay"]["weights"] = np.concatenate([p.flatten() for p in model_VGGwd_params])
np.save("vgg_results.npy",VGG_results_dict)
# Out:
# Train Epoch: 1
# 	Train set: Average loss: 2.2316
# 	Validation set: Average loss: 2.0387, Accuracy: 1099/5000 (22%)
# Train Epoch: 2
# 	Train set: Average loss: 1.9689
# 	Validation set: Average loss: 1.8993, Accuracy: 1433/5000 (29%)
# Train Epoch: 3
# 	Train set: Average loss: 1.7730
# 	Validation set: Average loss: 1.7707, Accuracy: 1626/5000 (33%)
# Train Epoch: 4
# 	Train set: Average loss: 1.6114
# 	Validation set: Average loss: 1.7294, Accuracy: 1799/5000 (36%)
# Train Epoch: 5
# 	Train set: Average loss: 1.4941
# 	Validation set: Average loss: 1.4123, Accuracy: 2397/5000 (48%)
# Train Epoch: 6
# 	Train set: Average loss: 1.3547
# 	Validation set: Average loss: 1.2865, Accuracy: 2599/5000 (52%)
# Train Epoch: 7
# 	Train set: Average loss: 1.2297
# 	Validation set: Average loss: 1.3769, Accuracy: 2587/5000 (52%)
# Train Epoch: 8
# 	Train set: Average loss: 1.1073
# 	Validation set: Average loss: 1.3439, Accuracy: 2715/5000 (54%)
# Train Epoch: 9
# 	Train set: Average loss: 1.0061
# 	Validation set: Average loss: 1.0767, Accuracy: 3090/5000 (62%)
# Train Epoch: 10
# 	Train set: Average loss: 0.8723
# 	Validation set: Average loss: 1.0049, Accuracy: 3198/5000 (64%)
# Train Epoch: 11
# 	Train set: Average loss: 0.7516
# 	Validation set: Average loss: 1.1758, Accuracy: 3126/5000 (63%)
# Train Epoch: 12
# 	Train set: Average loss: 0.6672
# 	Validation set: Average loss: 1.9976, Accuracy: 2492/5000 (50%)
# Train Epoch: 13
# 	Train set: Average loss: 0.5648
# 	Validation set: Average loss: 1.1063, Accuracy: 3316/5000 (66%)
# Train Epoch: 14
# 	Train set: Average loss: 0.4663
# 	Validation set: Average loss: 1.4061, Accuracy: 2986/5000 (60%)
# Train Epoch: 15
# 	Train set: Average loss: 0.3870
# 	Validation set: Average loss: 1.2725, Accuracy: 3306/5000 (66%)
# Train Epoch: 16
# 	Train set: Average loss: 0.3165
# 	Validation set: Average loss: 1.5118, Accuracy: 3176/5000 (64%)
# Train Epoch: 17
# 	Train set: Average loss: 0.2666
# 	Validation set: Average loss: 1.2561, Accuracy: 3325/5000 (66%)
# Train Epoch: 18
# 	Train set: Average loss: 0.2198
# 	Validation set: Average loss: 1.3224, Accuracy: 3358/5000 (67%)
# Train Epoch: 19
# 	Train set: Average loss: 0.1898
# 	Validation set: Average loss: 1.3344, Accuracy: 3314/5000 (66%)
# Train Epoch: 20
# 	Train set: Average loss: 0.1556
# 	Validation set: Average loss: 1.5003, Accuracy: 3356/5000 (67%)
# Train Epoch: 21
# 	Train set: Average loss: 0.1268
# 	Validation set: Average loss: 1.4744, Accuracy: 3411/5000 (68%)
# Train Epoch: 22
# 	Train set: Average loss: 0.1186
# 	Validation set: Average loss: 1.4857, Accuracy: 3461/5000 (69%)
# Train Epoch: 23
# 	Train set: Average loss: 0.1030
# 	Validation set: Average loss: 1.4500, Accuracy: 3461/5000 (69%)
# Train Epoch: 24
# 	Train set: Average loss: 0.0890
# 	Validation set: Average loss: 1.5351, Accuracy: 3439/5000 (69%)
# Train Epoch: 25
# 	Train set: Average loss: 0.0851
# 	Validation set: Average loss: 1.4072, Accuracy: 3526/5000 (71%)
# Train Epoch: 26
# 	Train set: Average loss: 0.0523
# 	Validation set: Average loss: 1.5896, Accuracy: 3479/5000 (70%)
# Train Epoch: 27
# 	Train set: Average loss: 0.0484
# 	Validation set: Average loss: 1.7260, Accuracy: 3469/5000 (69%)
# Train Epoch: 28
# 	Train set: Average loss: 0.0752
# 	Validation set: Average loss: 1.4831, Accuracy: 3476/5000 (70%)
# Train Epoch: 29
# 	Train set: Average loss: 0.0545
# 	Validation set: Average loss: 1.6484, Accuracy: 3446/5000 (69%)
# Train Epoch: 30
# 	Train set: Average loss: 0.0502
# 	Validation set: Average loss: 1.6224, Accuracy: 3492/5000 (70%)
#
# Test accuracy for best epoch: 71%

# %% [markdown]
# Simple CNN L2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = SimpleCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), 
                      lr=model_args['lr'],
                      weight_decay=0.)

train_loss_l2, val_loss_l2, best_accuracy = run_training(model, device, criterion, optimizer, model_args['epochs'],
                                                         L1_lambda=0.,
                                                         L2_lambda=model_args['L2_lambda']/2.)

print('\nTest accuracy for best epoch: {:.0f}%\n'.format(100.*best_accuracy))
plot_loss(train_loss_l2, val_loss_l2, 'L2 implemented by hand')
model_l2_params = [p.detach().cpu().numpy() for p in model.parameters()]

CNN_results_dict["L2"]["train loss"] = train_loss_l2
CNN_results_dict["L2"]["val loss"] = val_loss_l2
CNN_results_dict["L2"]["best accuracy"] = best_accuracy
CNN_results_dict["L2"]["weights"] = np.concatenate([p.flatten() for p in model_l2_params])

# %% [markdown]
# VGG11 L2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = VGG(make_layers(vgg_cfg['vgg11'])).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), 
                      lr=model_args['lr'],
                      weight_decay=0.)

train_loss_l2, val_loss_l2, best_accuracy = run_training(model, device, criterion, optimizer, model_args['epochs'],
                                                         L1_lambda=0.,
                                                         L2_lambda=model_args['L2_lambda']/2.)

print('\nTest accuracy for best epoch: {:.0f}%\n'.format(100.*best_accuracy))
plot_loss(train_loss_l2, val_loss_l2, 'VGG11 L2 implemented by hand')
model_VGGl2_params = [p.detach().cpu().numpy() for p in model.parameters()]

VGG_results_dict["L2"]["train loss"] = train_loss_l2
VGG_results_dict["L2"]["val loss"] = val_loss_l2
VGG_results_dict["L2"]["best accuracy"] = best_accuracy
VGG_results_dict["L2"]["weights"] = np.concatenate([p.flatten() for p in model_VGGl2_params])
np.save("vgg_results.npy",VGG_results_dict)
# Out:
# Train Epoch: 1
# 	Train set: Average loss: 2
# Train Epoch: 23
# 	Train set: Average loss: 0.7808
# 	Validation set: Average loss: 0.9734, Accuracy: 3310/5000 (66%)
# Train Epoch: 24
# 	Train set: Average loss: 0.7388
# 	Validation set: Average loss: 1.2763, Accuracy: 2980/5000 (60%)
# Train Epoch: 25
# 	Train set: Average loss: 0.7024
# 	Validation set: Average loss: 1.3545, Accuracy: 2830/5000 (57%)
# Train Epoch: 26
# 	Train set: Average loss: 0.6614
# 	Validation set: Average loss: 1.0489, Accuracy: 3226/5000 (65%)
# Train Epoch: 27
# 	Train set: Average loss: 0.6137
# 	Validation set: Average loss: 1.0658, Accuracy: 3306/5000 (66%)
# Train Epoch: 28
# 	Train set: Average loss: 0.5885
# 	Validation set: Average loss: 1.0263, Accuracy: 3313/5000 (66%)
# Train Epoch: 29
# 	Train set: Average loss: 0.5398
# 	Validation set: Average loss: 0.9902, Accuracy: 3420/5000 (68%)
# Train Epoch: 30
# 	Train set: Average loss: 0.5243
# 	Validation set: Average loss: 1.0578, Accuracy: 3267/5000 (65%)
#
# Test accuracy for best epoch: 69%

# %% [markdown]
# Simple CNN L2_lambda=L1_lambda

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = SimpleCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), 
                      lr=model_args['lr'],
                      weight_decay=0.)

train_loss_l2, val_loss_l2, best_accuracy = run_training(model, device, criterion, optimizer, model_args['epochs'],
                                                         L1_lambda=model_args['L2_lambda']/2.,
                                                         L2_lambda=model_args['L2_lambda']/2.)

print('\nTest accuracy for best epoch: {:.0f}%\n'.format(100.*best_accuracy))
plot_loss(train_loss_l2, val_loss_l2, 'Simple CNN L2_lambda=L1_lambda')
model_l1l2_params = [p.detach().cpu().numpy() for p in model.parameters()]

CNN_results_dict["L2=L1"]["train loss"] = train_loss_l2
CNN_results_dict["L2=L1"]["val loss"] = val_loss_l2
CNN_results_dict["L2=L1"]["best accuracy"] = best_accuracy
CNN_results_dict["L2=L1"]["weights"] = np.concatenate([p.flatten() for p in model_l1l2_params])

# %% [markdown]
# VGG11 L2_lambda=L1_lambda

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = VGG(make_layers(vgg_cfg['vgg11'])).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), 
                      lr=model_args['lr'],
                      weight_decay=0.)

train_loss_l1, val_loss_l1, best_accuracy = run_training(model, device, criterion, optimizer, model_args['epochs'],
                                                         L1_lambda=model_args['L2_lambda']/2.,
                                                         L2_lambda=model_args['L2_lambda']/2.)

print('\nTest accuracy for best epoch: {:.0f}%\n'.format(100.*best_accuracy))
plot_loss(train_loss_l1, val_loss_l1, 'VGG11 L2_lambda=L1_lambda')
model_vggl1l2_params = [p.detach().cpu().numpy() for p in model.parameters()]

VGG_results_dict["L2=L1"]["train loss"] = train_loss_l1
VGG_results_dict["L2=L1"]["val loss"] = val_loss_l1
VGG_results_dict["L2=L1"]["best accuracy"] = best_accuracy
VGG_results_dict["L2=L1"]["weights"] = np.concatenate([p.flatten() for p in model_vggl1l2_params])
np.save("vgg_results.npy",VGG_results_dict)
# Out:
# Train Epoch: 1
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3030, Accuracy: 491/5000 (10%)
# Train Epoch: 2
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3028, Accuracy: 477/5000 (10%)
# Train Epoch: 3
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3027, Accuracy: 500/5000 (10%)
# Train Epoch: 4
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3030, Accuracy: 500/5000 (10%)
# Train Epoch: 5
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3028, Accuracy: 489/5000 (10%)
# Train Epoch: 6
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3025, Accuracy: 500/5000 (10%)
# Train Epoch: 7
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3032, Accuracy: 502/5000 (10%)
# Train Epoch: 8
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3029, Accuracy: 500/5000 (10%)
# Train Epoch: 9
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3029, Accuracy: 489/5000 (10%)
# Train Epoch: 10
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3030, Accuracy: 502/5000 (10%)
# Train Epoch: 11
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3028, Accuracy: 502/5000 (10%)
# Train Epoch: 12
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3030, Accuracy: 477/5000 (10%)
# Train Epoch: 13
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3027, Accuracy: 489/5000 (10%)
# Train Epoch: 14
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3028, Accuracy: 500/5000 (10%)
# Train Epoch: 15
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3027, Accuracy: 502/5000 (10%)
# Train Epoch: 16
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3027, Accuracy: 500/5000 (10%)
# Train Epoch: 17
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3029, Accuracy: 500/5000 (10%)
# Train Epoch: 18
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3027, Accuracy: 502/5000 (10%)
# Train Epoch: 19
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3029, Accuracy: 491/5000 (10%)
# Train Epoch: 20
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3028, Accuracy: 500/5000 (10%)
# Train Epoch: 21
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3028, Accuracy: 489/5000 (10%)
# Train Epoch: 22
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3028, Accuracy: 477/5000 (10%)
# Train Epoch: 23
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3028, Accuracy: 502/5000 (10%)
# Train Epoch: 24
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3027, Accuracy: 500/5000 (10%)
# Train Epoch: 25
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3028, Accuracy: 529/5000 (11%)
# Train Epoch: 26
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3026, Accuracy: 502/5000 (10%)
# Train Epoch: 27
# 	Train set: Average loss: 2.3024
# 	Validation set: Average loss: 2.3028, Accuracy: 501/5000 (10%)
# Train Epoch: 28
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3028, Accuracy: 500/5000 (10%)
# Train Epoch: 29
# 	Train set: Average loss: 2.3026
# 	Validation set: Average loss: 2.3028, Accuracy: 500/5000 (10%)
# Train Epoch: 30
# 	Train set: Average loss: 2.3027
# 	Validation set: Average loss: 2.3028, Accuracy: 502/5000 (10%)
#
# Test accuracy for best epoch: 10%

# %% [markdown]
# Simple CNN L1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = SimpleCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), 
                      lr=model_args['lr'],
                      weight_decay=0.)

train_loss_l1, val_loss_l1, best_accuracy = run_training(model, device, criterion, optimizer, model_args['epochs'],
                                                         L1_lambda=model_args['L1_lambda'],
                                                         L2_lambda=0.)

print('\nTest accuracy for best epoch: {:.0f}%\n'.format(100.*best_accuracy))
plot_loss(train_loss_l1, val_loss_l1, 'Simple CNN L1 implemented by hand')
model_l1_params = [p.detach().cpu().numpy() for p in model.parameters()]

CNN_results_dict["L1"]["train loss"] = train_loss_l1
CNN_results_dict["L1"]["val loss"] = val_loss_l1
CNN_results_dict["L1"]["best accuracy"] = best_accuracy
CNN_results_dict["L1"]["weights"] = np.concatenate([p.flatten() for p in model_l1_params])

# %% [markdown]
# VGG11 L1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = VGG(make_layers(vgg_cfg['vgg11'])).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), 
                      lr=model_args['lr'],
                      weight_decay=0.)

train_loss_l1, val_loss_l1, best_accuracy = run_training(model, device, criterion, optimizer, model_args['epochs'],
                                                         L1_lambda=model_args['L1_lambda'],
                                                         L2_lambda=0.)

print('\nTest accuracy for best epoch: {:.0f}%\n'.format(100.*best_accuracy))
plot_loss(train_loss_l1, val_loss_l1, 'VGG, L1 implemented by hand')
model_vggl1_params = [p.detach().cpu().numpy() for p in model.parameters()]

VGG_results_dict["L1"]["train loss"] = train_loss_l1
VGG_results_dict["L1"]["val loss"] = val_loss_l1
VGG_results_dict["L1"]["best accuracy"] = best_accuracy
VGG_results_dict["L1"]["weights"] = np.concatenate([p.flatten() for p in model_vggl1_params])
np.save("vgg_results.npy",VGG_results_dict)
# Out:
# Train Epoch: 1
# 	Train set: Average loss: 2.2671
# 	Validation set: Average loss: 2.1593, Accuracy: 924/5000 (18%)
# Train Epoch: 2
# 	Validation set: Average loss: 1.8712, Accuracy: 1700/5000 (34%)
# Train Epoch: 25
# 	Train set: Average loss: 1.5413
# 	Validation set: Average loss: 1.5449, Accuracy: 2048/5000 (41%)
# Train Epoch: 26
# 	Train set: Average loss: 1.5251
# 	Validation set: Average loss: 1.6375, Accuracy: 1964/5000 (39%)
# Train Epoch: 27
# 	Train set: Average loss: 1.5058
# 	Validation set: Average loss: 1.4957, Accuracy: 2203/5000 (44%)
# Train Epoch: 28
# 	Train set: Average loss: 1.4991
# 	Validation set: Average loss: 1.4504, Accuracy: 2222/5000 (44%)
# Train Epoch: 29
# 	Train set: Average loss: 1.4779
# 	Validation set: Average loss: 1.5799, Accuracy: 2019/5000 (40%)
# Train Epoch: 30
# 	Train set: Average loss: 1.4810
# 	Validation set: Average loss: 1.4339, Accuracy: 2261/5000 (45%)
#
# Test accuracy for best epoch: 47%

# %%
np.save("cnn_results.npy",CNN_results_dict)

# %%
plt.rcParams.update({'font.size': 12})

plt.grid(True)
plt.xlabel("subsequent epochs")
plt.ylabel('average loss')
range_epochs = model_args['epochs']+1
plt.plot(range(1, range_epochs), train_loss_0,  'o-', label='train_vanilla')
plt.plot(range(1, range_epochs), train_loss_wd, 'o-', label='train_weight_decay')
plt.plot(range(1, range_epochs), train_loss_l2, 'o-', label='train_L2')
plt.plot(range(1, range_epochs), train_loss_l1, 'o-', label='train_L1')
plt.legend()
plt.title("regularizers comparison - training")
plt.show()

plt.grid(True)
plt.xlabel("subsequent epochs")
plt.ylabel('average loss')
range_epochs = model_args['epochs']+1
plt.plot(range(1, range_epochs), val_loss_0,  'o-', label='validation_vanilla')
plt.plot(range(1, range_epochs), val_loss_wd, 'o-', label='validation_weight_decay')
plt.plot(range(1, range_epochs), val_loss_l2, 'o-', label='validation_L2')
plt.plot(range(1, range_epochs), val_loss_l1, 'o-', label='validation_L1')
plt.legend()
plt.title("regularizers comparison - validation")
plt.show()

# %% [markdown]
# Example weights:

# %%
for p in model_0_params:
    print(p.shape)

np.set_printoptions(formatter={'float_kind': "{:.3f}".format})
# parameters for the second from last layer
print("vanilla:\n", model_0_params[-2][0])
print("L2 regularized:\n", model_l2_params[-2][0])
print("L1 regularized:\n", model_l1_params[-2][0])

# %% [markdown]
# ### Tasks to do:
#
# 0. Try to play with L2 and L1 *lambdas* do get highest possible accuracy.
# - e.g. what if we increase *L1_lambda* to be the same as *L2_lambda*
# 1. Repeat the calculations but for the VGG11 model.
# 2. Compare amplitudes (plot histograms?) of model weights for the L2 and L1 case -- is L1 a strong feature selector?
#
# 3. Reimplement pytorch [SGD method](https://pytorch.org/docs/stable/_modules/torch/optim/sgd.html#SGD) to get L1 regularization (|w| instead of w**2)
#
# Hint: change line
# ```python
# if weight_decay != 0:
#     d_p = d_p.add(param, alpha=weight_decay)
# ```
# to
# ```python
# if weight_decay != 0:
#     d_p = d_p.add(torch.sign(param), alpha=weight_decay)
# ```
